# %% [markdown]
# # Exercises in Recommender systems
#
# This notebook contains exercises in Recommender systems

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Exercise 1
#
# Using the "Coursera Courses Dataset 2021" available at kaggle ([https://www.kaggle.com/datasets/khusheekapoor/coursera-courses-dataset-2021](https://www.kaggle.com/datasets/khusheekapoor/coursera-courses-dataset-2021)) or on moodle, to do the following:
#
# 1. Create a Content-based filtering recommender system based on the Course Descriptions.
# 2. Create a Content-based filtering recommender system based on the Skills.
#
# Using the "Book Recommendation Dataset" available at kaggle ([https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset](https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset)) or on moodle, to do the following:
#
# 3. Load in the `Ratings.csv` file (on moodle, it is called `Books_Ratings.csv`). Group by `User-ID` and sort by `Book-Rating` in descending order to get the users who rated most books. Filter the rating data to only contain the 200 users that rated most books.
# 4. Create a Collaborative filtering recommender system based on the user ratings from 3 together with the `Books.csv` dataset.

# %% [markdown]
# 1. Create a Content-based filtering recommender system based on the Course Descriptions.

# %%
courses = pd.read_csv("Coursera.csv")
courses.head(2)
# Out:
#                                          Course Name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
#
#                   University Difficulty Level Course Rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
#
#                                   Course Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
#
#                                               Skills
# 0  Drama  Comedy  peering  screenwriting  film  D...
# 1  Finance  business plan  persona (user experien...

# %%
courses["Course Description"].head()
# Out:
# 0    Write a Full Length Feature Film Script  In th...
# 1    By the end of this guided project, you will be...
# 2    This course consists of a general presentation...
# 3    When it comes to numbers, there is always more...
# 4    In this course you�ll learn how to effectively...
# Name: Course Description, dtype: object

# %%
courses["Course Description"].isna().sum()
# Out:
# np.int64(0)

# %%
tfidf = TfidfVectorizer(stop_words="english")

# %%
tfidf_matrix = tfidf.fit_transform(courses["Course Description"])

# %%
tfidf_matrix.shape
# Out:
# (3522, 20074)

# %%
tfidf_matrix.toarray()[1, :]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], shape=(20074,))

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 253718 stored elements and shape (3522, 20074)>

# %%
# %%time
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
# Out:
# CPU times: total: 250 ms
# Wall time: 255 ms

# %% [markdown]
# # Since you have used the TF-IDF vectorizer, calculating the dot product between each vector will directly give you the cosine similarity score. Therefore, you will use sklearn's linear_kernel() instead of cosine_similarities() since it is faster.

# %%
##from sklearn.metrics.pairwise import linear_kernel

# %%
# %%time
# cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim
# Out:
# array([[1.00000000e+00, 3.12366523e-02, 1.97603991e-02, ...,
#         3.17538002e-02, 3.33859933e-02, 1.96231367e-02],
#        [3.12366523e-02, 1.00000000e+00, 8.58915185e-03, ...,
#         3.13671991e-02, 4.88239107e-03, 4.56033552e-02],
#        [1.97603991e-02, 8.58915185e-03, 1.00000000e+00, ...,
#         3.45669421e-03, 1.65197252e-02, 6.37237740e-03],
#        ...,
#        [3.17538002e-02, 3.13671991e-02, 3.45669421e-03, ...,
#         1.00000000e+00, 5.07544593e-04, 6.72367274e-03],
#        [3.33859933e-02, 4.88239107e-03, 1.65197252e-02, ...,
#         5.07544593e-04, 1.00000000e+00, 1.14068789e-03],
#        [1.96231367e-02, 4.56033552e-02, 6.37237740e-03, ...,
#         6.72367274e-03, 1.14068789e-03, 1.00000000e+00]],
#       shape=(3522, 3522))

# %% [markdown]
# Matrix is symmetric:

# %%
cosine_sim[0, 1]
# Out:
# np.float64(0.0312366522978012)

# %%
cosine_sim[1, 0]
# Out:
# np.float64(0.0312366522978012)

# %% [markdown]
# Reverse map of index index to Course Names

# %%
indices = pd.Series(courses.index, index=courses["Course Name"]).drop_duplicates()

# %% [markdown]
# The below shows that similarity score from "cosine_sim[0, 1]" is the similarity between courses Write a Feature.... and Business Strategy....

# %%
indices[0:5]
# Out:
# Course Name
# Write A Feature Length Screenplay For Film Or Television       0
# Business Strategy: Business Model Canvas Analysis with Miro    1
# Silicon Thin Film Solar Cells                                  2
# Finance for Managers                                           3
# Retrieve Data using Single-Table SQL Queries                   4
# dtype: int64

# %%
def get_recommendations(course_name, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[course_name]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return courses["Course Name"].iloc[movie_indices]

# %%
get_recommendations("Write A Feature Length Screenplay For Film Or Television")
# Out:
# 1481    Script Writing: Write a Pilot Episode for a TV...
# 1629                               Write Your First Novel
# 3481                                   Transmedia Writing
# 2186         Presentation skills: Public Speaking Project
# 3445                   Better Business Writing in English
# 3384              English for Effective  Business Writing
# 2894    Automating Team Communication with Google Shee...
# 614                      Writing in English at University
# 2732    Writing Professional Email and Memos (Project-...
# 104                                      Business Writing
# Name: Course Name, dtype: object

# %% [markdown]
# 2. Create a Content-based filtering recommender system based on the Skills.

# %%
courses["Skills"].head()
# Out:
# 0    Drama  Comedy  peering  screenwriting  film  D...
# 1    Finance  business plan  persona (user experien...
# 2    chemistry  physics  Solar Energy  film  lambda...
# 3    accounts receivable  dupont analysis  analysis...
# 4    Data Analysis  select (sql)  database manageme...
# Name: Skills, dtype: object

# %%
courses["Skills"].isna().sum()
# Out:
# np.int64(0)

# %%
tfidf_matrix_skills = tfidf.fit_transform(courses["Skills"])

# %%
tfidf_matrix_skills.shape
# Out:
# (3522, 4337)

# %%
# %%time
cosine_sim_skills = cosine_similarity(tfidf_matrix_skills, tfidf_matrix_skills)
# Out:
# CPU times: total: 141 ms
# Wall time: 159 ms

# %%
cosine_sim_skills
# Out:
# array([[1.        , 0.        , 0.05204333, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.        , ..., 0.20061523, 0.        ,
#         0.01306076],
#        [0.05204333, 0.        , 1.        , ..., 0.        , 0.1787157 ,
#         0.00490933],
#        ...,
#        [0.        , 0.20061523, 0.        , ..., 1.        , 0.        ,
#         0.03178263],
#        [0.        , 0.        , 0.1787157 , ..., 0.        , 1.        ,
#         0.00459616],
#        [0.        , 0.01306076, 0.00490933, ..., 0.03178263, 0.00459616,
#         1.        ]], shape=(3522, 3522))

# %%
cosine_sim_skills[0, 1]
# Out:
# np.float64(0.0)

# %%
cosine_sim_skills[1, 0]
# Out:
# np.float64(0.0)

# %% [markdown]
# No similarity, the ciusine similarity is (close to) 0, aka orthogonal.

# %%
indices_skills = pd.Series(courses.index, index=courses["Course Name"]).drop_duplicates()

# %%
indices_skills[0:5]
# Out:
# Course Name
# Write A Feature Length Screenplay For Film Or Television       0
# Business Strategy: Business Model Canvas Analysis with Miro    1
# Silicon Thin Film Solar Cells                                  2
# Finance for Managers                                           3
# Retrieve Data using Single-Table SQL Queries                   4
# dtype: int64

# %%
get_recommendations("Write A Feature Length Screenplay For Film Or Television", cosine_sim_skills)
# Out:
# 1451    Creative Writing: The Craft of Setting and Des...
# 1481    Script Writing: Write a Pilot Episode for a TV...
# 3462                 Creative Writing: The Craft of Style
# 2424                      Writing Stories About Ourselves
# 3005                             Writing a Personal Essay
# 339     Memoir and Personal Essay: Managing Your Relat...
# 3481                                   Transmedia Writing
# 535                 Writing in First Person Point of View
# 1629                               Write Your First Novel
# 3255                         So You Think You Know Tango?
# Name: Course Name, dtype: object

# %% [markdown]
# Using the "Book Recommendation Dataset" available at kaggle ([https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset](https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset)) or on moodle, to do the following:
#
# 3. Load in the `Ratings.csv` file (on moodle, it is called `Books_Ratings.csv`). Group by `User-ID` and sort by `Book-Rating` in descending order to get the users who rated most books. Filter the rating data to only contain the 200 users that rated most books.

# %%
ratings = pd.read_csv("Books_Ratings.csv")
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
user_rating_count = ratings.groupby("User-ID").size() ## Num of rows pr group
user_rating_count
# Out:
# User-ID
# 2          1
# 7          1
# 8         18
# 9          3
# 10         2
#           ..
# 278846     2
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Length: 105283, dtype: int64

# %%
top_200_users = user_rating_count.sort_values(ascending=False).head(200).index

# %%
filtered_ratings = ratings[ratings["User-ID"].isin(top_200_users)]
filtered_ratings
# Out:
#          User-ID        ISBN  Book-Rating
# 4330      278418  0006128831            0
# 4331      278418  0006542808            5
# 4332      278418  0020209606            0
# 4333      278418  0020418809            0
# 4334      278418  0020420900            0
# ...          ...         ...          ...
# 1147612   275970  3829021860            0
# 1147613   275970  4770019572            0
# 1147614   275970   896086097            0
# 1147615   275970  9626340762            8
# 1147616   275970  9626344990            0
#
# [288349 rows x 3 columns]

# %% [markdown]
# 4. Create a Collaborative filtering recommender system based on the user ratings from 3 together with the `Books.csv` dataset.

# %%
books = pd.read_csv("Books.csv")
books.head(2)
# Out:
# C:\Users\Jacob\AppData\Local\Temp\ipykernel_21952\4187753225.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("Books.csv")
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
df = books.merge(filtered_ratings, how="left", on="ISBN")
df.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L  User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/0195153448.0...      NaN          NaN
# 1  http://images.amazon.com/images/P/0002005018.0...  11676.0          8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414693 entries, 0 to 414692
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 414693 non-null  object
#  1   Book-Title           414693 non-null  object
#  2   Book-Author          414691 non-null  object
#  3   Year-Of-Publication  414693 non-null  object
#  4   Publisher            414691 non-null  object
#  5   Image-URL-S          414693 non-null  object
#  6   Image-URL-M          414693 non-null  object
#  7   Image-URL-L          414690 non-null  object
#  8   User-ID              270629 non-null  float64
#  9   Book-Rating          270629 non-null  float64
# dtypes: float64(2), object(8)
# memory usage: 31.6+ MB

# %%
df.shape
# Out:
# (414693, 10)

# %%
df["Book-Title"].nunique()
# Out:
# 242135

# %%
df["User-ID"].nunique()
# Out:
# 200

# %% [markdown]
# Theres 414693 ratings by users, and they are made by the 200 users we selected before (out of 242135 unique books). However, not all books has a rating neccesarely, which we will adress:

# %%
df[["Book-Title","Book-Rating"]].isna().sum()
# Out:
# Book-Title          0
# Book-Rating    144064
# dtype: int64

# %% [markdown]
# We see that there is 144064 books that have no rating

# %%
df[["Book-Title","Book-Rating"]].dropna().drop(columns=["Book-Rating"]).value_counts()
# Out:
# Book-Title
# Bridget Jones's Diary                                                                                         117
# Wild Animus                                                                                                   100
# The Pelican Brief                                                                                              99
# Message in a Bottle                                                                                            97
# The Notebook                                                                                                   93
#                                                                                                              ...
# Ã?Â?lpiraten.                                                                                                   1
#  Deceived                                                                                                       1
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)      1
# Ã?Â?stlich der Berge.                                                                                           1
#  Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth                1
# Name: count, Length: 115766, dtype: int64

# %% [markdown]
# Dropping the missing values, we see that there is 115766 books rated (by the 200 users)

# %% [markdown]
# We now create a new DF, containing only the User ID's, the Book titles and the Rating for the book that the user (might not) have given

# %%
user_rating_books_df = df[["User-ID", "Book-Title", "Book-Rating"]]

# %%
user_rating_books_df
# Out:
#          User-ID                                         Book-Title  \
# 0            NaN                                Classical Mythology
# 1        11676.0                                       Clara Callan
# 2       177458.0                                       Clara Callan
# 3            NaN                               Decision in Normandy
# 4       197659.0  Flu: The Story of the Great Influenza Pandemic...
# ...          ...                                                ...
# 414688       NaN                         There's a Bat in Bunk Five
# 414689       NaN                            From One to One Hundred
# 414690       NaN  Lily Dale : The True Story of the Town that Ta...
# 414691       NaN                        Republic (World's Classics)
# 414692       NaN  A Guided Tour of Rene Descartes' Meditations o...
#
#         Book-Rating
# 0               NaN
# 1               8.0
# 2               0.0
# 3               NaN
# 4               9.0
# ...             ...
# 414688          NaN
# 414689          NaN
# 414690          NaN
# 414691          NaN
# 414692          NaN
#
# [414693 rows x 3 columns]

# %% [markdown]
# We now convert the dataset into a "user-item" matrix (wide-format). That is, each row will represent a unique user. And each column will represent a unique book title, along with the rating the user (might not, aka NaN) have given.

# %%
user_rating_books_df = user_rating_books_df.pivot_table(index=["User-ID"], columns=["Book-Title"], values="Book-Rating")

# %%
user_rating_books_df.head()
# Out:
# Book-Title   A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   NaN
#
# Book-Title   Always Have Popsicles   Apple Magic (The Collector's series)  \
# User-ID
# 3363.0                         NaN                                    NaN
# 6251.0                         NaN                                    NaN
# 6575.0                         NaN                                    NaN
# 7346.0                         NaN                                    NaN
# 11601.0                        NaN                                    NaN
#
# Book-Title   Beyond IBM: Leadership Marketing and Finance for the 1990s  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   0.0
#
# Book-Title   Dark Justice   Deceived  \
# User-ID
# 3363.0                NaN        NaN
# 6251.0                NaN        NaN
# 6575.0                NaN        NaN
# 7346.0                NaN        NaN
# 11601.0               NaN        NaN
#
# Book-Title   Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   NaN
#
# Book-Title   Final Fantasy Anthology: Official Strategy Guide (Brady Games)  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   NaN
#
# Book-Title   Garfield Bigger and Better (Garfield (Numbered Paperback))  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   NaN
#
# Book-Title   Good Wives: Image and Reality in the Lives of Women in Northern New England, 1650-1750  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   NaN
#
# Book-Title  ...  whataboutrick.com: a poetic tribute to Richard A. Ricci  \
# User-ID     ...
# 3363.0      ...                                                NaN
# 6251.0      ...                                                NaN
# 6575.0      ...                                                NaN
# 7346.0      ...                                                NaN
# 11601.0     ...                                                NaN
#
# Book-Title  Â¡Corre, perro, corre!  Â¡Cristina! confidencias de una rubia  \
# User-ID
# 3363.0                         NaN                                    NaN
# 6251.0                         NaN                                    NaN
# 6575.0                         NaN                                    NaN
# 7346.0                         NaN                                    NaN
# 11601.0                        NaN                                    NaN
#
# Book-Title  Â¿Eres tu mi mamÃ¡?/Are You My Mother?  Â¿QuÃ© me quieres, amor?  \
# User-ID
# 3363.0                                         NaN                       NaN
# 6251.0                                         NaN                       NaN
# 6575.0                                         NaN                       NaN
# 7346.0                                         NaN                       NaN
# 11601.0                                        NaN                       NaN
#
# Book-Title  Ã?ber den Wunsch, sich wohlzufÃ¼hlen: Geschichten  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   NaN
#
# Book-Title  Ã?Â?ber das Fernsehen.  \
# User-ID
# 3363.0                         NaN
# 6251.0                         NaN
# 6575.0                         NaN
# 7346.0                         NaN
# 11601.0                        NaN
#
# Book-Title  Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    NaN
# 11601.0                                                   NaN
#
# Book-Title  Ã?Â?lpiraten.  Ã?Â?stlich der Berge.
# User-ID
# 3363.0                NaN                    NaN
# 6251.0                NaN                    NaN
# 6575.0                NaN                    NaN
# 7346.0                NaN                    NaN
# 11601.0               NaN                    NaN
#
# [5 rows x 115766 columns]

# %%
user_rating_books_df.shape
# Out:
# (200, 115766)

# %% [markdown]
# We are now ready to build the recommender. We take the User-iD, 7346, as a start. We get the books that user 7346 has rated:

# %%
user_7346_df = user_rating_books_df[user_rating_books_df.index == 7346]
user_7346_df
# Out:
# Book-Title   A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title   Always Have Popsicles   Apple Magic (The Collector's series)  \
# User-ID
# 7346.0                         NaN                                    NaN
#
# Book-Title   Beyond IBM: Leadership Marketing and Finance for the 1990s  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title   Dark Justice   Deceived  \
# User-ID
# 7346.0                NaN        NaN
#
# Book-Title   Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title   Final Fantasy Anthology: Official Strategy Guide (Brady Games)  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title   Garfield Bigger and Better (Garfield (Numbered Paperback))  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title   Good Wives: Image and Reality in the Lives of Women in Northern New England, 1650-1750  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title  ...  whataboutrick.com: a poetic tribute to Richard A. Ricci  \
# User-ID     ...
# 7346.0      ...                                                NaN
#
# Book-Title  Â¡Corre, perro, corre!  Â¡Cristina! confidencias de una rubia  \
# User-ID
# 7346.0                         NaN                                    NaN
#
# Book-Title  Â¿Eres tu mi mamÃ¡?/Are You My Mother?  Â¿QuÃ© me quieres, amor?  \
# User-ID
# 7346.0                                         NaN                       NaN
#
# Book-Title  Ã?ber den Wunsch, sich wohlzufÃ¼hlen: Geschichten  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title  Ã?Â?ber das Fernsehen.  \
# User-ID
# 7346.0                         NaN
#
# Book-Title  Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.  \
# User-ID
# 7346.0                                                    NaN
#
# Book-Title  Ã?Â?lpiraten.  Ã?Â?stlich der Berge.
# User-ID
# 7346.0                NaN                    NaN
#
# [1 rows x 115766 columns]

# %%
user_7346_books_rated = user_7346_df.columns[user_7346_df.notna().any()].tolist()
user_7346_books_rated
# Out:
# ['10,000 Things to Praise God for',
#  '101 Dalmatians',
#  '1984',
#  '36 Hour Day : A Family Guide to Caring for Person with          Alzheimer Disease',
#  'A 2nd Helping of Chicken Soup for the Soul (Chicken Soup for the Soul Series (Paper))',
#  'A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash',
#  'A CLEAR CASE OF MURDER',
#  'A Child Called \\It\\": One Child\'s Courage to Survive"',
#  'A Civil Action',
#  'A Cow on the Line and Other Thomas the Tank Engine Stories (Please Read to Me)',
#  'A DRAGON IN THE FAMILY : A DRAGON IN THE FAMILY',
#  'A Dark Traveling',
#  'A Fool for Murder: A Mystery',
#  'A Girl of the Limberlost',
#  'A Great Day for the Deadly',
#  'A Hog on Ice and Other Curious Expressions (Harper Colophon Books)',
#  'A Kiss Gone Bad',
#  'A Lesson Before Dying (Vintage Contemporaries)',
#  'A Light in the Window (The Mitford Years)',
#  'A Little Princess',
#  "A Midsummer Night's Dream",
#  'A Most Contagious Game',
#  'A Murderous Yarn (Needlecraft Mysteries)',
#  'A Night to Remember',
#  'A Nose for Murder',
#  'A Pedigree to Die for',
#  'A Pirate Looks at Fifty',
#  'A Prayer for Owen Meany',
#  'A RIVER RUNS THROUGH IT AND OTHER STORIES : AND OTHER STORIES',
#  'A Rock and a Hard Place (Star Trek The Next Generation, No 10)',
#  'A Short Guide to a Happy Life',
#  'A Walk Across America',
#  'A Widow for One Year',
#  'A Wind in the Door',
#  'A Wizard in a Feud',
#  'A Wrinkle in Time',
#  'ALL-OF-A-KIND FAMILY DOWNTOWN',
#  'Absolute Power',
#  'Across China',
#  'Adjusted to Death',
#  'Adventures of Tom Sawyer',
#  'Aeneid of Virgil',
#  'Agatha Raisin and the Love from Hell (An Agatha Raisin Mystery)',
#  'Alf: Mission to Mars',
#  'Alice-by-Accident',
#  'All Creatures Great and Small',
#  'All I Need to Know I Learned from My Cat',
#  'All I Really Need to Know I Learned from Watching Star Trek',
#  'All Things Bright and Beautiful',
#  'All Things Bright and Beautiful (All Things Bright &amp; Beautiful)',
#  'All the Crazy Winters',
#  'Along Came a Spider (Alex Cross Novels)',
#  'Amber Brown Is Not a Crayon (Amber Brown (Paperback))',
#  'American Gods',
#  'American Notes for General Circulation (Penguin Classics)',
#  'American Way of Death',
#  'An Episode of Sparrows',
#  'And No Birds Sang',
#  "Angela's Ashes (MMP) : A Memoir",
#  'Angus, Thongs and Full-Frontal Snogging: Confessions of Georgia Nicolson',
#  'Animal Farm',
#  'Anne of Avonlea (Anne of Green Gables Novels (Paperback))',
#  'Anne of Green Gables (Anne of Green Gables Novels (Paperback))',
#  'Anne of Green Gables (Bantam Starfire Book)',
#  'Anne of Green Gables: Three Volumes in One',
#  'Anne of Ingleside (Anne of Green Gables Novels (Paperback))',
#  'Anne of Windy Poplars (Anne of Green Gables Novels (Paperback))',
#  "Anne's House of Dreams",
#  'Another City, Not My Own: A Novel in the Form of a Memoir',
#  'Apollo 13 : Lost Moon',
#  'April Fool Dead : A Death on Demand Mystery (Death on Demand Mysteries (Paperback))',
#  'As You Like It (New Penguin Shakespeare S.)',
#  'As You Like It (Shakespeare, William, Works.)',
#  'At Home in Mitford (The Mitford Years)',
#  'At the Back of the North Wind (Puffin Classics)',
#  'At the Manger: The Stories of Those Who Were There',
#  'Atlantis Found',
#  "Attack of the Jack-O'-Lanterns (Goosebumps, 48)",
#  'Attack/Killer Tomatoes PT N Mk',
#  'Aunt Dimity and the Duke (Penguin Crime Fiction)',
#  "Aunt Dimity's Death (Aunt Dimity (Paperback))",
#  "Aunt Erma's Cope Book",
#  'Auntie Mayhem (Bed-And-Breakfast Mysteries (Paperback))',
#  'Babe: The Gallant Pig',
#  'Babywatching',
#  "Bachelor Brothers' Bed &amp; Breakfast",
#  'Back to School Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'Ballerina!',
#  "Beaches II: I'll Be There",
#  "Been There Should'Ve Done That: 505 Tips for Making the Most of College",
#  'Beezus and Ramona',
#  "Beginner's Luck (Ballantine Reader's Circle)",
#  'Behind the Scenes at the Museum : A Novel',
#  'Bel Canto: A Novel',
#  'Beyond Mulder and Scully: The Mysterious Characters of \\the X-Files\\""',
#  "Big Cherry Holler: A Big Stone Gap Novel (Ballantine Reader's Circle)",
#  "Big Stone Gap: A Novel (Ballantine Reader's Circle)",
#  'Birthday Party Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'Black Notice',
#  'Bleeding Hearts (The Gregor Demarkian Holiday Series)',
#  'Blue eyeshadow should still be illegal: The world after Retin-A : what do you do now?',
#  'Book of Lists',
#  'Booked to Die (Cliff Janeway Novels (Paperback))',
#  'Bradshaw on the Family: A Revolutionary Way of Self Discovery',
#  'Bridget Jones : The Edge of Reason',
#  "Bridget Jones's Diary",
#  "Buzz Beamer's Out of This World Series",
#  'CLAUDINE AT ST CLARES',
#  'CROSSCURRENTS (NANCY DREW FILES 68) : CROSSCURRENTS (Nancy Drew Files, No 68)',
#  "CUCKOO'S EGG",
#  'Call of the Wild',
#  'Castle Roogna #03',
#  'Castle of Wizardry (The Belgariad, Book 4)',
#  'Casual Day Has Gone Too Far',
#  'Cat Under Fire : A Joe Grey Mystery',
#  'Cats and Their Women',
#  'Cave (One Small Square Series)',
#  'Centaur Aisle',
#  "Changing Times: The Story of a Tennessee Walking Horse and the Girl Who Proves That Grown-Ups Don't Always Know Best (Treasured Horses)",
#  'Charlie and the Chocolate Factory (Puffin Novels)',
#  "Charlotte's Web",
#  "Charlotte's Web (Trophy Newbery)",
#  'Chicken Soup for the Soul (Chicken Soup for the Soul)',
#  'Chicken Soup for the Teenage Soul (Chicken Soup for the Soul)',
#  'Children Learn What They Live: Parenting to Inspire Values',
#  'Chocolat',
#  'Chocolate Chip Cookie Murder (Hannah Swensen Mysteries (Paperback))',
#  'Chocolate Chippo Hippo (Beginning Literacy Stage C)',
#  'Chosen Prey',
#  'Christmas Cookie Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'Christmas Spirits',
#  'Christy',
#  'Clear and Present Danger (Jack Ryan Novels)',
#  'Coast To Coast Ghosts',
#  'Cold Comfort Farm',
#  'Cold Mountain : A Novel',
#  'Come to Grief',
#  'Confessions of a Shopaholic (Summer Display Opportunity)',
#  'Confessions of an Ugly Stepsister : A Novel',
#  'Conversations With God : An Uncommon Dialogue (Book 2)',
#  'Cooking School Murders',
#  'Coraline',
#  'Coroner',
#  'Courting Trouble',
#  'Creed for the Third Millennium',
#  'Crewel Lye',
#  'Crewel World (Needlecraft Mysteries)',
#  'Crime Brulee (Culinary Mysteries (Paperback))',
#  'Crime and Punishment (Wordsworth Classics)',
#  'Crocodile on the Sandbank',
#  'Crossing Antarctica',
#  "Crows Can't Count",
#  'Crystal Line',
#  'Crystal Singer',
#  'DAUGHTER OF TIME',
#  'Daddies: All About the Work They Do (Little Golden Books)',
#  'Dance upon the Air (Three Sisters Island Trilogy)',
#  'Dancing On My Grave Gelsey Kirkland',
#  'Dancing With Tigers',
#  'Dare to Discipline',
#  'Dark Place',
#  'Dead Man Walking: An Eyewitness Account of the Death Penalty in the United States',
#  "Dead Man's Island",
#  'Dead Men Do Tell Tales: The Strange and Fascinating Cases of a Forensic Anthropologist',
#  'Dead Poets Society',
#  'Dead in the Melon Patch (Amanda Hazard Mysteries)',
#  'Deadline for a Critic',
#  'Deadly Shaker Spring (Sister Rose Callahan Mystery)',
#  'Deadly Valentine',
#  "Death a L'Orange",
#  "Death of a Fool (St. Martin's Dead Letter Mysteries.)",
#  'Death of a Party Animal (A Doonesbury book)',
#  'Death of an Angel (Sister Mary Helen Mystery)',
#  'Diary of a Provincial Lady (Provincial Lady)',
#  'Died to Match',
#  'Dilbert Fugitive From The Cubicle Police',
#  'Dilbert: Seven Years Of Highly Defective People (P',
#  "Dirk Gently's Holistic Detective Agency",
#  'Disclosure',
#  'Discourses (Penguin Classics)',
#  'Divine Secrets of the Ya-Ya Sisterhood: A Novel',
#  'Do Unto Others',
#  "Don't Say Yes When You Want to Say No : Making Life Right When It Feels All Wrong",
#  'Double Crossing (Nancy Drew/Hardy Boys Super Mystery, No 1)',
#  'Dr Zhivago',
#  'Dr. Jekyll and Mr. Hyde',
#  'Dragon Tears',
#  'Dragon on a Pedestal',
#  'Dragonquest',
#  'Dragonsinger',
#  'Dreyfus Affair : Love Story, A',
#  'Drinking : A Love Story',
#  'Driving Force',
#  'Dying for Chocolate (Culinary Mysteries (Paperback))',
#  "Edward VII's Last Loves",
#  'Eight Million Ways To Die',
#  'Eighth Dwarf',
#  'Elegy for Iris',
#  'Eli',
#  'Ellen Tebbits',
#  'Elusive Mrs. Pollifax',
#  'Emotional Intelligence : Why It Can Matter More Than IQ',
#  'Empire Falls',
#  "Enchanters' End Game (The Belgariad, Book 5)",
#  'Encyclopedia Brown Finds the Clues (Encyclopedia Brown (Paperback))',
#  'Encyclopedia Brown Keeps the Peace (Encyclopedia Brown (Paperback))',
#  'Encyclopedia Brown Saves the Day (Encyclopedia Brown (Paperback))',
#  'Encyclopedia Brown Takes the Case (Encyclopedia Brown (Paperback))',
#  "Encyclopedia Brown and the Case of Pablo's Nose (Encyclopedia Brown (Paperback))",
#  'Encyclopedia Brown: Boy Detective (Encyclopedia Brown (Paperback))',
#  'Escape from Camp Run-for-Your-Life (Give Yourself Goosebumps, No 19)',
#  'Escape the Night',
#  'Euripides Ten Plays',
#  'Euthypro, Crito, Apology, and Symposium',
#  'Eva Moves the Furniture: A Novel',
#  'F Is for Fugitive (Kinsey Millhone Mysteries (Paperback))',
#  'FIFTH FORMERS ST CLARES',
#  'FINAL NOTES (NANCY DREW FILES 65) : FINAL NOTES (Nancy Drew Files, No 65)',
#  'FIRST WIVES CLUB',
#  'FUGITIVE TRAIL',
#  'Face the Fire (Three Sisters Island Trilogy)',
#  'Fall Of Camp A-555 (Vietnam Ground Zero, No 4)',
#  'Family Picture',
#  'Fatal Cure',
#  'Feel the Fear and Do It Anyway',
#  "Felicia's Journey",
#  'Final Cut',
#  'Fingersmith',
#  "Finnegan's Week",
#  'Fires of Spring -3',
#  'Firestorm (Anna Pigeon Mysteries (Paperback))',
#  'Five Patients',
#  'Five Sisters : The Langhornes  of Virginia',
#  'Fletch',
#  'Flight of the Old Dog',
#  "Flowers on My Grave: How an Ojibwa Boy's Death Helped Break the Silence on Child Abuse",
#  'Fool Moon (The Dresden Files, Book 2)',
#  'For Better, for Worse: A Novel',
#  'For Kicks',
#  "Fortune's Rocks : A Novel",
#  'Four Against the Odds: The Struggle to Save Our Environment (Scholastic Biography)',
#  "Four Comedies/the Taming of the Shrew/a Midsummer Night's Dream/the Merchant of Venice/Twelfth Night (Bantam Classics)",
#  'Four Stupid Cupids (The Hamlet Chronicles)',
#  'Four To Score (A Stephanie Plum Novel)',
#  'Framed in Lace (Needlecraft Mysteries)',
#  'Freaky Friday',
#  'Freckles (Deluxe Illustrated Classic Series)',
#  'From Beginning to End: The Rituals of Our Lives',
#  "From Potter's Field",
#  'G Is for Gumshoe (Kinsey Millhone Mysteries (Paperback))',
#  'GHOST SHIP ST TRK (Star Trek the Next Generation, Book #2)',
#  'GOING FOR GOLD',
#  'GREEN GROW DOLLARS',
#  'Games to Keep the Dark Away',
#  'Garden of Shadows (Dollanganger)',
#  'Garfield Takes Up Space (Garfield, No 20)',
#  'Gaudy Night',
#  'Gem Of A Girl (Harlequin Romance)',
#  'Gift from the Sea',
#  'Gift from the sea',
#  'Gigi (French language edition)',
#  'Girl With a Pearl Earring',
#  'Girl in Hyacinth Blue',
#  'God at Eventide',
#  "God's Promises for the Graduate",
#  'Golem in the Gears (Xanth Novels (Paperback))',
#  'Gone with the Wind',
#  'Good Morning, Miss Dove',
#  'Good in Bed',
#  'Good-Bye to Guilt: Releasing Fear Through Forgiveness',
#  'Grania: She-King of the Irish Seas',
#  'Graven Images (Newbery Honor Roll)',
#  'Growing Pains of Adrian Mole',
#  'Gruel and Unusual Punishment: A Pennsylvania Dutch Mystery With Recipes (Pennsylvania Dutch Mysteries with Recipes (Paperback))',
#  'Guards! Guards! (Discworld Novels (Paperback))',
#  'H Is for Homicide (Kinsey Millhone Mysteries (Paperback))',
#  'HOT PURSUIT (NANCY DREW FILES 58) : HOT PURSUIT (The Nancy Drew Files, Case No. 58)',
#  'HOW DID I GET TO BE 40 &amp; OTHER ATROCITIES',
#  'Hair of the Dog: A Melanie Travis Mystery (Melanie Travis Mystery)',
#  'Hamlet',
#  'Hanging by a Thread (Ferris, Monica. Needlecraft Mysteries.)',
#  'Hard Time (V.I. Warshawski Novels (Paperback))',
#  'Hard Times (Watermill)',
#  'Harry Potter and the Prisoner of Azkaban (Book 3)',
#  "Harry Potter and the Sorcerer's Stone (Book 1)",
#  'Hawaii',
#  'Hearts in Atlantis',
#  'Hello Darling, Are You Working?',
#  'Henry and Beezus (Henry Huggins (Paperback))',
#  'Henry and Ribsy (Henry Huggins (Paperback))',
#  "Henry's Awful Mistake",
#  "Her Majesty's Wizard",
#  'Herbal Remedy Gardens: 38 Plans for Your Health &amp; Well-Being',
#  "Hidden Agendas (Tom Clancy's Net Force, No. 2)",
#  'High Fidelity',
#  'High Five (A Stephanie Plum Novel)',
#  'High Seas Murder: A Lindy Haggerty Mystery',
#  'Highland Fling',
#  "Hinds' Feet on High Places",
#  "Hitchhikers's Guide to the Galaxy",
#  'Homecoming',
#  'Hons and Rebels',
#  'Hornblower #07 Flying Color',
#  'Hot Six : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#  'House of Sand and Fog',
#  'How Many Animals Down Ladybug Lane (A Little Look Around Book)',
#  'How Stella Got Her Groove Back',
#  'How to Fight Back and Win: The Joy of Self-Defense',
#  'How to Make Good Pictures',
#  'How to Murder Your Mother-In-Law',
#  'How to Prepare for Your High School Reunion and Other Midlife Musings',
#  'Hunger Point : A Novel',
#  'Hunting Season (Anna Pigeon Novels (Paperback))',
#  'I Capture the Castle',
#  'I Lost Everything in the Post-Natal Depression',
#  'I, Houdini: The Amazing Story of an Escape-Artist Hamster',
#  'I, Trissy',
#  'IF THERE BE THORN',
#  'Iberia: Spanish Travels and Reflections',
#  'Icy Clutches',
#  "If I'd Killed Him When I Met Him (Elizabeth MacPherson Novels (Paperback))",
#  'Imitation in Death (Eve Dallas Mysteries (Paperback))',
#  'In Her Shoes : A Novel',
#  "In a Different Voice: Psychological Theory and Women's Development",
#  'In the Line of Fire: Eight Women War Spies',
#  'Independence Day',
#  'Indian Trail',
#  'Interview with the Vampire',
#  'Into Thin Air : A Personal Account of the Mt. Everest Disaster',
#  'Into the Dark for Gold',
#  'Irish Stew! (Nuala McGrail Mystery)',
#  'Island of the Blue Dolphins (Laurel Leaf Books)',
#  'It Was on Fire When I Lay Down on It',
#  "It's Always Something",
#  'JOSHUA',
#  'JOURNEY INTO DARKNESS (Lisa Drew Books (Paperback))',
#  'Jacob Have I Loved',
#  "James Herriot's Dog Stories",
#  'Jane Austen: A Life',
#  'Jelly Belly',
#  "Jewel (Oprah's Book Club)",
#  'Joshua',
#  'Journey to the Centre of the Earth (Puffin Classics)',
#  'Junie B. Jones and Her Big Fat Mouth (Junie B. Jones 3, paper)',
#  'Jurassic Park',
#  "KB IRELAND'99:INNS&amp;ITIN (Karen Brown's Country Inns Series)",
#  "Karen's Little Witch (Baby-Sitters Little Sister, 22)",
#  'Killashandra',
#  'Killer Dolphin',
#  'Killing Orders',
#  'Kilmeny of the Orchard (Bantam Classics)',
#  'King Arthur and the Knights of the Round Table (Illustrated Classics Editions)',
#  "King Solomon's Mines (Puffin Classics)",
#  'Kiss the Girls',
#  'Kit Carson Scout (Vietnam Ground Zero, No 6)',
#  'Kitchen',
#  'Lady Molly of Scotland Yard',
#  "Lady's Maid",
#  'Lake Wobegon days',
#  "Laurel's Kitchen: A Handbook for Vegetarian Cookery and Nutrition",
#  'Lavender Lies: A China Bayles Mystery (Prime Crime Mysteries)',
#  'Lazaris the Sacred Journey: You and Your Higher Self',
#  'Leaving Home',
#  'Legally Blonde',
#  'Les Liaisons Dangereuses',
#  'Les Miserables (Enriched Classics)',
#  "Let's Get Invisible! (Goosebumps, No 6)",
#  'Liberty Falling (Anna Pigeon Mysteries (Paperback))',
#  "Life 101: Everything We Wish We Had Learned About Life in School--But Didn't (The Life 101 Series)",
#  "Life 101: Everything We Wish We Had Learned in High School-But Didn't",
#  "Life Messages: Inspiration For The Woman's Spirit",
#  "Life's Little Instruction Book (Life's Little Instruction Books (Paperback))",
#  'Like Water for Chocolate : A Novel in Monthly Installments with Recipes, Romances, and Home Remedies',
#  'Like Water for Chocolate: A Novel in Monthly Installments With Recipes, Romances and Home Remedies',
#  'Lion in the Valley',
#  'Little Drummer Girl',
#  'Little Women',
#  'Little Women (Illustrated Junior Library)',
#  'Living without losing: A practical guide to successful living',
#  "Lord Foulgrin's Letters",
#  'Lord God Made Them All',
#  'Lord of the Dance',
#  'Love in the Time of Cholera (Penguin Great Books of the 20th Century)',
#  "Love, Medicine and Miracles : Lessons Learned about Self-Healing from a Surgeon's Experience with Exceptional Patients",
#  'Lovely in Her Bones',
#  "Lucifer's Hammer",
#  'Lucifers Hammer',
#  'Lucky : A Memoir',
#  'MAN IN QUEUE',
#  'MANY WATERS',
#  'MISS PYM DISPOSES',
#  'MOONLIGHT BECOMES YOU',
#  'MOVING TARGET (NANCY DREW FILES 87) : MOVING TARGET (Nancy Drew Files (Paperback))',
#  'MURDER COMES 1ST (Mr. &amp; Mrs. North Mystery)',
#  'MURDER MAKE WHEELS',
#  'MYSTERY OF THE JADE TIGER (NANCY DREW 104) : MYSTERY OF THE JADE TIGER',
#  'Macbeth',
#  'Macbeth (Bantam Classics)',
#  'Macv (Vietnam Ground Zero, No 19)',
#  'Madeline',
#  'Malice Domestic  7 (Malice Domestic (Paperback))',
#  'Man Called Intrepid',
#  'Man from Mundania (Xanth Trilogy, No 12)',
#  'Man of the House',
#  'Massage and Meditation',
#  'Matilda',
#  'Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships',
#  'Menopaws: The Silent Meow',
#  'Mere Christianity: A revised and enlarged edition, with a new introduction, of the three books, The case for Christianity, Christian behaviour, and Beyond personality',
#  'Metropolitan Life',
#  'Michelle Kwan Autobiography',
#  'Midnight',
#  'Midwives: A Novel',
#  "Millie's Book: As Dictated to Barbara Bush",
#  'Mind Prey',
#  'Mindbend',
#  'Mine Eyes Have Seen',
#  'Mint Julep Murder',
#  'Misery',
#  "Miss Fannie's Hat (Picture Puffins)",
#  "Miss Fiona's Fancy (Signet Regency Romance)",
#  'Miss Julia Hits the Road (Southern Comedy of Manners)',
#  'Miss Julia Throws a Wedding',
#  'Miss Melville Regrets',
#  'Miss Melville Returns',
#  'Miss Melville Rides a Tiger',
#  "Miss Melville's Revenge",
#  "Miss Seeton Paints the Town (Heron Carvic's Miss Seeton)",
#  'Miss Seeton by Moonlight',
#  'Miss Silver Comes to Stay',
#  'Miss Silver Deals With Death: A Miss Silver Mystery',
#  'Mistletoe Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'Mitch and Amy',
#  'Moment of Truth',
#  'Monster Blood (Goosebumps, No 3)',
#  'More Cats in the Belfry',
#  'More Than a Carpenter',
#  'Moreta: Dragonlady of Pern',
#  'Mountains of Spices',
#  'Moving Violations : War Zones, Wheelchairs, and Declarations of Independence',
#  'Mr. Death and the Redheaded Woman (A Star &amp; elephant book)',
#  'Mrs. Jeffries Pinches the Post',
#  'Mrs. Jeffries Takes the Cake',
#  "Mrs. Piggle-Wiggle's Magic",
#  'Mrs. Pollifax Pursued (Mrs. Pollifax Mysteries (Paperback))',
#  'Mrs. Pollifax Unveiled (Mrs. Pollifax Mysteries (Paperback))',
#  'Murder Carries a Torch : A Southern Sisters Mystery (Southern Sisters Mysteries (Paperback))',
#  'Murder Gets a Life: : A Southern Sisters Mystery (Southern Sisters Mysteries (Paperback))',
#  'Murder Pluperfect (Walker British Mystery Series)',
#  'Murder Shoots the Bull : A Southern Sisters Mystery (Southern Sisters Mysteries (Paperback))',
#  'Murder at the Cat Show (A Perkins &amp; Tate Mystery)',
#  'Murder at the Kennedy Center (Capital Crime Mysteries)',
#  'Murder at the National Cathedral (Capital Crime Mysteries)',
#  'Murder in Georgetown (Capital Crime Mysteries)',
#  'Murder in the CIA (Capital Crime Mysteries)',
#  'Murder in the House (Capital Crime Series , No 13)',
#  'Murder in the White House',
#  'Murder on a Bad Hair Day: A Southern Sisters Mystery',
#  'Murder, Mayhem And Mistletoe',
#  'Murdering Mr. Monti: A Merry Little Tale of Sex and Violence',
#  'Mutation',
#  'My Enemy the Queen',
#  'My First Book of Opposites',
#  'My Wild World',
#  'My Year of Meats',
#  'Mysteries (Mystery)',
#  'Mysteries of the Mind and the Senses (Strange Unsolved Mysteries, No 8)',
#  'Mystery Cats',
#  'Mystery of the Tolling Bell (Nancy Drew Mystery Stories, No 23)',
#  'N Is for Noose',
#  "NOBODY'S BUSINESS: NANCY DREW FILES #67 (Nancy Drew Files, No 67)",
#  "Naked in Baghdad: The Iraq War as Seen by NPR's Correspondent Anne Garrels",
#  'Naked in Death',
#  "Nancy Drew's Guide to Life (Running Press Miniature Editions (Paperback))",
#  'Native Speaker',
#  'Nerd in Shining Armor',
#  'Nickel and Dimed: On (Not) Getting By in America',
#  'Nicolae: The Rise of Antichrist (Left Behind No. 3)',
#  'Night Mare #06',
#  'Night Prey',
#  'Night of the Living Dummy (Goosebumps, No 7)',
#  'No Ordinary Genius: The Illustrated Richard Feynman',
#  'Not a Penny More 4',
#  'Not a Penny More, Not a Penny Less',
#  'Nothings Fair in the Fifth Grade',
#  'Now We Are Six',
#  'O Come Ye Back to Ireland: Our First Year in County Clare',
#  'Odd Girl Out: The Hidden Culture of Aggression in Girls',
#  'Of Love and Shadows',
#  'Of Mice and Men',
#  'Ogre Ogre #05',
#  'Olive and the Magic Hat',
#  'On a Pale Horse',
#  'On the Street Where You Live',
#  'Once upon a More Enlightened Time: More Politically Correct Bedtime Stories',
#  "One Flew Over the Cuckoo's Nest",
#  'One True Thing',
#  'One for the Money (Stephanie Plum Novels (Paperback))',
#  'One of the Third Grade Thonkers',
#  'Organize Your Office!: Simple Routines for Managing Your Workspace',
#  'Our Looks, Our Lives: Sex, Beauty, Power, and the Need to Be Seen',
#  "Out of Harm's Way: The Extraordinary True Story of One Woman's Lifelong Devotion to Animal Rescue",
#  'Oz #06: Emerald City of Oz',
#  'Ozma of Oz',
#  'P Is for Peril (Kinsey Millhone Mysteries (Hardcover))',
#  'P.O.W. (Vietnam Ground Zero, No 2)',
#  'PARTNERSHIP (Brainship)',
#  'POISON PEN (NANCY DREW FILES 60) : POISON PEN (Nancy Drew Files, No. 60)',
#  'Pamela',
#  'Parallel Lives: Five Victorian Marriages',
#  'Passing Fancy (Alien Nation, Book 6)',
#  'Paste Makes Waste (Powerpuff Girls (Unnumbered).)',
#  "Paul Harvey's Rest of the Story",
#  'Pay Dirt, Or, Adventures at Ash Lawn',
#  'Peace Like a River',
#  'Pemberley or Pride and Prejudice Continued',
#  'People of Pern',
#  'Perimenopause Preparing for the Change: A Guide to the Early Stages of Menopause and Beyond',
#  'Personal History',
#  'Piano Lessons Can Be Murder (Goosebumps, No 13)',
#  'Pippi in the South Seas (Puffin Books)',
#  'Piranha to Scurfy: And Other Stories',
#  'Plague Dogs',
#  'Plainsong (Vintage Contemporaries)',
#  'Poison in the Pen',
#  'Poland',
#  'Pop Goes the Weasel',
#  'Pop Out Drive: Diggers Dumpers',
#  'Portrait in Sepia : A Novel',
#  'Power Play',
#  "Practical Cogitator: The Thinker's Anthology",
#  'Press On! Further Adventures in the Good Life',
#  'Presumed Innocent',
#  'Pretty Polly',
#  'Pride and Prejudice',
#  'Pride and Prejudice (The Penguin English Library, El 72)',
#  'Primary Colors: A Novel of Politics',
#  'Prime Cut',
#  'Princess in the Spotlight (The Princess Diaries, Vol. 2)',
#  'Private Screening',
#  'Prostho Plus',
#  'Provincial Lady in London (Provincial Lady)',
#  'Pure Drivel',
#  'QUIVER FULL ARROWS',
#  'Queen of Sorcery (Eddings, David. , the Belgariad, Bk. 2.)',
#  'RED DRAGON',
#  'ROAD LESS TRAVELED : A New Psychology of Love, Traditional Values, and Spritual Growth (Touchstone Books (Paperback))',
#  'ROMEO JULIET',
#  'RUNNING SCARED: NANCY DREW FILES #69 (Nancy Drew Files, No 69)',
#  'Rainbow Valley (Anne of Green Gables Novels (Paperback))',
#  'Raise High the Roof Beam, Carpenters and Seymour: An Introduction',
#  'Ramona Forever (Ramona Quimby (Paperback))',
#  'Ramona and Her Father (Ramona Quimby (Paperback))',
#  'Ramona the Brave (Ramona Quimby (Paperback))',
#  'Ramona the Pest (Ramona Quimby (Paperback))',
#  'Reading Lolita in Tehran : A Memoir in Books',
#  'Rebecca',
#  'Rebecca of Sunnybrook Farm',
#  'Recessional',
#  'Red Azalea',
#  'Red Dust (Vietnam Ground Zero, No 13)',
#  'Red Square',
#  'Regarding the Fountain (An Avon Camelot Book)',
#  "Regina's Glasses (Early Success - Level 2, Book 17 of 30)",
#  'Republic of Plato',
#  'Rescuing the Bible from Fundamentalism : A Bishop Rethinks the Meaning of Scripture',
#  'Rest in Pieces (Mrs. Murphy Mysteries (Paperback))',
#  'Return from the Inferno (Wingman , No 9)',
#  'Revenge Of The Barbeque Queens : At The Barbeque World Series, More Than Ribs Will Be Swimming In Sauce (A Heaven Lee Culinary Mystery)',
#  'Revenge of the Lawn Gnomes (Goosebumps #34)',
#  'Rhaeva',
#  'Rich Dad, Poor Dad: What the Rich Teach Their Kids About Money--That the Poor and Middle Class Do Not!',
#  'Rising Sun',
#  'Robin Hood of Sherwood Forest',
#  'Romana Quimby, Age 8',
#  'Romance',
#  'Romeo and Juliet',
#  'Rosemary Remembered',
#  'Roses Are Red (Alex Cross Novels)',
#  'Round Ireland With a Fridge',
#  'Ruff Way to Go (Allie Babcock Mysteries)',
#  'Rumpole and the Golden Thread',
#  'SECOND FORM ST CLARES',
#  'SECRET OF THE TIBETAN TREASURE (NANCY DREW 108) : SECRET OF THE TIBETAN TREASURE (NANCY DREW ON CAMPUS)',
#  'SEEDS OF YESTERDY (Dollanger Saga (Paperback))',
#  'SHIPPING NEWS',
#  'STONES FROM THE RIVER',
#  'SUMMER TERM AT ST CLARES',
#  'SWISS SECRETS PASSPORT TO ROMANCE 1 (NANCY DREW FILES 72) : SWISS SECRETS PASSPORT TO ROMANCE 1 (Passport to Romance Trilogy, No 1)',
#  'Sacred Sins',
#  'Saratoga Snapper (Penguin Crime Fiction)',
#  'Say Cheese and Die! (Goosebumps, No 4)',
#  'Scandal in Fair Haven',
#  'Scarlet Pimpernel (Complete and Unabridged Classics)',
#  'Searoad: Chronicles of Klatsand',
#  'Secret of the Ninja',
#  'Secrets of the Flesh: A Life of Colette',
#  'Seduction in Death',
#  'Selecting and Caring for Your Cat',
#  'Separation of Power',
#  'Seven Pillars of Wisdom: A Triumph',
#  'Seven Up (A Stephanie Plum Novel)',
#  'Seven for a Secret',
#  "Shakespeare's Stories: Comedies",
#  'She Said Yes: The Unlikely Martyrdom of Cassie Bernall',
#  'She Walks These Hills',
#  'She Went All the Way (Avon Light Contemporary Romances)',
#  'Shell Seekers',
#  'Shining Through',
#  'Shopaholic Takes Manhattan (Summer Display Opportunity)',
#  'Shopaholic Ties the Knot',
#  'Shopgirl',
#  'Shore to Die',
#  'Show Baby: 1 2 3',
#  'Sick of Shadows',
#  'Sidetracked Sisters Happiness File',
#  'Silas Marner (Bantam Classics)',
#  'Silence of the Lambs',
#  'Silver Scream : A Bed-and-Breakfast Mystery (Bed-And-Breakfast Mysteries (Paperback))',
#  "Simon's Book",
#  'Simple Path',
#  'Sisterhood of the Traveling Pants',
#  'Skeleton Dance (Gideon Oliver Mysteries (Paperback))',
#  'Skeleton Key : A Gregor Demarkian Mystery (A Gregor Demarkian Mystery)',
#  'Skipping Christmas',
#  'Slam (Alloy Books)',
#  "Slaves in the Family (Ballantine Reader's Circle)",
#  "Smilla's Sense of Snow",
#  'Sniper (Super Vietnam Ground Zero, No 5)',
#  'Snow Falling on Cedars',
#  "Soldier'S Medal (Vietnam Ground Zero, No 5)",
#  'Sometimes I Need to Be Hugged: Psalm 84 for Children (Murphy, Elspeth Campbell. David and I Talk to God.)',
#  'Sophies Choice',
#  'Soul Harvest: The World Takes Sides (Left Behind No. 4)',
#  'Soulshaping: Taking Care of Your Spiritual Life Through Godly Disciplines',
#  'Southern Fried Makeover: Clueless (CLUELESS)',
#  'Southern Living Our Best One-Dish Meals (Southern Living)',
#  'Space',
#  'Special People',
#  'Spell for Chameleon #01',
#  "Spider's Web",
#  'Split Infinity (Apprentice Adept (Paperback))',
#  'Spoon River Anthology',
#  'Spycatcher',
#  'Stalking Lamb',
#  'Stalking the Perfect Tan',
#  'Star Trek III The Search for Spock (Star Trek, No 17)',
#  'Star wars: From the adventures of Luke Skywalker : a novel',
#  'Still Life with  Woodpecker',
#  'Still Pumped From Using The Mouse',
#  'Storm Front (The Dresden Files, Book 1)',
#  'Storytelling Stone: Traditional Native American Myths and Tales (Laurel Original)',
#  'Strange Creatures That Really Lived',
#  'Stray Kat Waltz (Kat Colorado Mysteries)',
#  'Strong Poison',
#  "Stud Rites: A Dog Lover's Mystery (Dog Lover's Mysteries)",
#  'Succulent Wild Woman',
#  'Suddenly Last Summer.',
#  'TALL, DARK AND DEADLY (NANCY DREW FILES 66) : TALL, DARK AND DEADLY (Nancy Drew Files, No. 66)',
#  'TANGLED WEB, A',
#  'TEARS OF RAGE',
#  'THREE TO GET DEADLY : A Stephanie Plum Novel',
#  'TWINS AT ST CLARES',
#  'Tales of S Pacific-3',
#  'Tales of a Fourth Grade Nothing',
#  'Tales of the City (Tales of the City Series, V. 1)',
#  'Talking from 9 to 5 : Women and Men at Work',
#  'Tan Son Nhut (Vietnam Ground Zero, No 20)',
#  'Tara Road',
#  'Teach Us, Amelia Bedelia  (Hello Reader!, Level 4)',
#  'Teachers! Teachers! Teachers!',
#  'Tell No One',
#  'The Abductors: Conspiracy',
#  'The Adams Chronicles: Four Generations of Greatness',
#  'The Adventures of Huckleberry Finn (Bantam Classics)',
#  'The Adventures of Mighty Mom',
#  'The Adventures of Milo and Otis',
#  'The Adventures of Tom Sawyer (Adventures of Tom Sawyer)',
#  'The Aeneid of Virgil (Bantam Classics)',
#  'The Amazing Adventures of Kavalier &amp; Clay',
#  'The Anastasia Syndrome',
#  'The Ape Who Guards the Balance : An Amelia Peabody Mystery',
#  'The Apprentice : A Novel',
#  "The Bachelor's Cat",
#  'The Bad Beginning (A Series of Unfortunate Events, Book 1)',
#  'The Beans of Egypt, Maine',
#  'The Berenstain Bear Scouts and the Sinister Smoke Ring (Berenstain Bear Scouts (Paperback))',
#  "The Best American Crime Writing: 2002 Edition : The Year's Best True Crime Reporting (Best American Crime Writing)",
#  'The Best Friend (Fear Street ) : The Best Friend',
#  'The Bishop and the Beggar Girl of St. Germain: A Blackie Ryan Storyr (Bishop Blackie Ryan Series)',
#  'The Bishop and the Missing L Train (Blackie Ryan)',
#  'The Blue Nowhere : A Novel',
#  'The Body Farm',
#  'The Boilerplate Rhino: Nature in the Eye of the Beholder',
#  'The Bone Collector (Lincoln Rhyme Novels (Paperback))',
#  "The Bonesetter's Daughter",
#  'The Bonfire of the Vanities',
#  'The Book of Five Rings (Gorin No Sho): The Real Art of Japanese Management',
#  'The Book of Fred : A Novel',
#  'The Borrowers',
#  'The Boy Next Door',
#  'The Brethren',
#  'The Bridled Groom',
#  'The Bungalow Mystery (Nancy Drew Mystery Stories, No 3)',
#  'The Burglar in the Rye: A Bernie Rhodenbarr Mystery (Bernie Rhodenbarr Mysteries (Paperback))',
#  'The Case of the Chocolate Fingerprints (Clue Jr.)',
#  'The Case of the Disappearing Princess (The New Adventures of Mary-Kate &amp; Ashley)',
#  'The Case of the Missing Mummy (Adventures of Mary-Kate and Ashley)',
#  'The Case of the Mystery Ghost (Clue Jr.)',
#  'The Cat Who Ate Danish Modern (Cat Who... (Paperback))',
#  'The Cat Who Could Read Backwards',
#  'The Catcher in the Rye',
#  'The Charm School',
#  "The Cheshire Cat's Eye",
#  'The Christie Caper',
#  'The Cider House Rules',
#  "The Clan of the Cave Bear (Earth's Children (Paperback))",
#  'The Clue in the Crumbling Wall (Nancy Drew Mystery Stories, No 22)',
#  'The Clue in the Jewel Box (Nancy Drew Mystery Stories, No 20)',
#  'The Clue in the Old Album (Nancy Drew Mystery Stories, No 24)',
#  'The Cobra Event',
#  'The Color Purple',
#  'The Color of Magic',
#  "The Color of Water: A Black Man's Tribute to His White Mother",
#  'The Creepy Creations of Professor Shock (Give Yourself Goosebumps, No 14)',
#  'The Crime Lovers Casebook',
#  "The Curse of the Mummy's Tomb (Goosebumps, No 5)",
#  "The Dance of Anger: A Woman's Guide to Changing the Patterns of Intimate Relationships",
#  'The Dead Cat Bounce : A Home Repair is Homicide Mystery (Home Repair is Homicide Mysteries (Paperback))',
#  "The Dive From Clausen's Pier : A Novel (Vintage Contemporaries (Paperback))",
#  'The Diving Bell and the Butterfly : A Memoir of Life in Death',
#  'The Egypt Game (Yearling Newbery)',
#  'The End of Work As We Know It',
#  'The End of the Pier',
#  'The Enneagram : A Journey of Self Discovery',
#  'The Final Deduction',
#  'The Final Judgment',
#  'The Final Storm (Wingman , No 6)',
#  'The Fire Engine Book (Golden Super Shape Books)',
#  'The Five People You Meet in Heaven',
#  'The Five Red Herrings',
#  'The Flame Trees of Thika: Memories of an African Childhood',
#  "The Florabama Ladies' Auxiliary &amp; Sewing Circle",
#  'The Fran Lebowitz Reader',
#  'The Ghost Next Door (Goosebumps, No 10)',
#  'The Girl Who Cried Monster (Goosebumps, No 8)',
#  'The Girl Who Heard Dragons',
#  "The Girls' Guide to Hunting and Fishing",
#  'The Giver (21st Century Reference)',
#  'The God of Small Things',
#  'The Godmother',
#  'The Golden Ball (Lady Lovelylocks and the Pixietails)',
#  'The Golden Compass (His Dark Materials, Book 1)',
#  'The Good Girl Syndrome',
#  'The Good Life',
#  'The Great Mom Swap',
#  'The Great Train Robbery',
#  'The Green Mile',
#  "The Hangman's Beautiful Daughter",
#  'The Haunted Lady',
#  'The Hidden Staircase (Nancy Drew Mystery Stories, No 2)',
#  'The Hills of Homicide',
#  'The Honourable Schoolboy',
#  'The Horse Whisperer',
#  'The Hot Zone',
#  'The Hours : A Novel',
#  'The House of Mirth',
#  'The House of the Spirits',
#  'The Indian in the Cupboard (rack) (Indian in the Cupboard)',
#  'The Island Of Heavenly Daze',
#  'The Joy Luck Club',
#  "The Kalahari Typing School for Men : More from the No. 1 Ladies' Detective Agency",
#  'The King of Torts',
#  "The Kitchen God's Wife",
#  'The Ladies of Missalonghi',
#  'The Last Hero : A Discworld Fable',
#  'The Last Resort: A Novel',
#  'The Last Victim : A True-Life Journey into the Mind of the Serial Killer',
#  'The Law of Similars',
#  'The Life of King Henry the Fifth',
#  'The Lion, the Witch, and the Wardrobe (The Chronicles of Narnia, Book 2)',
#  'The Long Loneliness',
#  "The Long Program : Skating Toward Life's Victories",
#  "The Lost Boy: A Foster Child's Search for the Love of a Family",
#  'The Lost Jewels of Nabooti',
#  'The Lottery Winner : Alvirah And Willy Stories',
#  'The Lovely Bones: A Novel',
#  'The Making of The African Queen',
#  'The Man Who Understood Cats (John Thinnes/Jack Caleb Mysteries)',
#  'The Map of Love',
#  'The Martian Chronicles',
#  'The Mayor of Casterbridge (Bantam Classics)',
#  'The Missing Madonna',
#  'The Mouse and the Motorcycle',
#  'The Mozart Effect : Tapping the Power of Music to Heal the Body, Strengthen the Mind, and Unlock the Creative Spirit',
#  'The Murder Game',
#  'The Murder at the Murder at the Mimosa Inn (Claire Malloy Mysteries (Paperback))',
#  'The Murder of Roger Ackroyd',
#  'The Murders of Richard III',
#  'The Mystery at Lilac Inn (Nancy Drew Mystery Stories, No 4)',
#  'The Nanny Diaries: A Novel',
#  'The National Parks : A Postcard Folio Book',
#  'The New New Thing : A Silicon Valley Story',
#  'The New Voyages (Star Trek)',
#  'The Next Karate Kid',
#  'The Night Before Christmas',
#  'The Night of Four Hundred Rabbits',
#  'The Nine Emotional Lives of Cats : A Journey Into the Feline Heart',
#  'The Not-Just-Anybody Family',
#  'The Notebook',
#  'The Novel',
#  "The O'SULLIVAN TWINS",
#  'The Old Contemptibles',
#  'The Only Good Yankee',
#  'The Other Boleyn Girl',
#  'The Passion of Artemisia',
#  'The Peacekeepers (Star Trek: The Next Generation, Book 2)',
#  'The Pelican Brief',
#  'The Peregrine Reader',
#  'The Perfect Murder: Five Great Mystery Writers Create the Perfect Crime',
#  'The Perfect Storm : A True Story of Men Against the Sea',
#  'The Phantom Tollbooth',
#  'The Pilgrim of Hate (Chronicle of Brother Cadfael, No 10)',
#  'The Pill Book: The Illustrated Guide to the Most Prescribed Druga in the U.S. (Pill Book (Mass Market Paper))',
#  'The Pistachio Prescription: A Novel',
#  'The Place at the Edge of the Earth',
#  'The Poisonwood Bible: A Novel',
#  'The Prince (Penguin Classics)',
#  'The Prince of Tides',
#  "The Princess Bride: S Morgenstern's Classic Tale of True Love and High Adventure",
#  'The Quest of the Missing Map (Nancy Drew (Hardcover))',
#  'The Rainmaker',
#  'The Red Badge of Courage (Bantam Classics)',
#  'The Red Dancer : The Life and Times of Mata Hari',
#  'The Return Journey',
#  'The Rules(TM) : Time-Tested Secrets for Capturing the Heart of Mr. Right',
#  'The Runaway Jury',
#  "The Saints' Guide to Happiness",
#  'The Second Lady',
#  'The Secret Diary of Adrian Mole Aged 13 3/4',
#  'The Secret in the Old Attic (Nancy Drew Mystery Stories, No 21)',
#  'The Secret of Red Gate Farm (Nancy Drew Mystery Stories, No 6)',
#  'The Secret of Shadow Ranch (Nancy Drew Mystery Stories, No 5)',
#  'The Secret of the Old Clock (Nancy Drew Mystery Stories, No 1)',
#  'The Sherluck Bones Mystery Detective Book No. 3 (Sherluck Bones Mystery)',
#  'The Sittaford Mystery',
#  'The Slave Ship',
#  'The Songcatcher: A Ballad Novel',
#  'The Soul of Celtic Spirituality: In the Lives of Its Saints',
#  'The Source of Magic',
#  'The Spell-Bound Scholar (The Warlock Series)',
#  'The Spy Wore Silk',
#  'The Stainless Steel Rat Saves the World (Stainless Steel Rat Books (Paperback))',
#  'The Street Lawyer',
#  'The Sum of All Fears',
#  'The Summons',
#  'The Sunday Tertulia',
#  "The Sweet Potato Queens' Book of Love",
#  'The Talented Mr. Ripley (Vintage Crime/Black Lizard)',
#  'The Taming of the Shrew: With New Dramatic Criticism and an Updated Bibliography (Signet Classic Shakespeare Series)',
#  'The Testament',
#  'The Thin Woman',
#  'The Tragedy of Hamlet Prince of Denmark (Signet Classic Shakespeare Series)',
#  'The True Confessions of Charlotte Doyle (rack)',
#  'The Truth Trap',
#  'The Truth: A Novel of Discworld',
#  'The Twisted Cross (Wingman , No 5)',
#  'The Two Mrs. Grenvilles',
#  'The Unbearable Lightness of Being',
#  'The Vanishing Hitchhiker: American Urban Legends and Their Meanings',
#  'The Warlock in Spite of Himself',
#  'The Way of the Bull',
#  'The Wednesday Surprise',
#  'The Weight of Water',
#  'The Westing Game (Now in Speak!)',
#  'The White Dragon (Dragonriders of Pern Vol 3)',
#  "The Wicked Flea: A Dog Lover's Mystery (Dog Lover's Mysteries)",
#  'The Wind in the Willows',
#  'The Wind in the Willows (Aladdin Classics)',
#  'The hug therapy book',
#  "Then Again, Maybe I Won't",
#  "There's a Bat in Bunk Five",
#  'Thin Man',
#  'Think about It Snoopy',
#  'Thousand Pieces of Gold: A Biographical Novel (Asian Voices)',
#  'Three Days for Emeralds',
#  'Three Investigators in the Mystery of the Coughing Dragon',
#  'Thunder in the East (Wingman , No 4)',
#  'Thyme of Death: A China Bayles Mystery (West Coast Crime)',
#  'Till Death',
#  'Tim',
#  'Timeline',
#  'Tippy-Toe Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'To Dream of Love',
#  'To Kill a Mockingbird',
#  'To Perish in Penzance (Dorothy Martin Mysteries (Hardcover))',
#  'To Say Nothing of the Dog',
#  'To the Nines: A Stephanie Plum Novel',
#  "Today I Am a Ma'Am: And Other Musings on Life, Beauty, and Growing Older",
#  'Total Recall: A V.I. Warshawski Novel',
#  'Touch Not the Cat',
#  'Toujours Provence (Vintage Departures)',
#  'Travels With My Aunt (Twentieth Century Classics)',
#  'Treason in America: From Aaron Burr to Averell Harriman',
#  "Trevor's Place: The Story of the Boy Who Brings Hope to the Homeless",
#  'Tribulation Force: The Continuing Drama of Those Left Behind (Left Behind No. 2)',
#  'Trick of Light',
#  'Trick or Treat Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'Trixie Belden and the Mystery of the Blinking Eye',
#  'Trixie Belden the Mystery of the Antique Doll (Trixie Belden)',
#  'Truffled Feathers',
#  'Trust Fund',
#  'Tuck Everlasting',
#  'Turkey Day Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'Twelve Red Herrings',
#  'Twisted (Point)',
#  'Two Weirdos and a Ghost',
#  'Two for the Dough',
#  'Unadulterated Cat',
#  'Unconfirmed Kill (Vietnam Ground Zero, No 3)',
#  'Under the Tuscan Sun',
#  'Underdog: A Melanie Travis Mystery',
#  'Unfit to Practice',
#  'Unraveled Sleeve (Needlecraft Mysteries)',
#  'Untimely Guest',
#  'Utopia : A Thriller',
#  'VEIL: SECRET WARS OF THE CIA : VEIL: SECRET WARS OF THE CIA',
#  'Valentine Murder: A Lucy Stone Mystery (Lucy Stone Mysteries (Paperback))',
#  'Vanishing Point: A Miss Silver Mystery',
#  'Violets Are Blue',
#  'WAITING TO EXHALE',
#  'WIND IN THE WILLOWS, THE',
#  'WLD ACCORDNG GARP',
#  'Waiting to Exhale',
#  'Waking Up In Time: Finding Inner Peace In Times of Accelerating Change',
#  "Walt Disney's Bambi",
#  'War Letters : Extraordinary Correspondence from American Wars',
#  'War of the Sun (Wingman, 10)',
#  'Warlock Unlocked',
#  "We Don't Die: George Anderson's Conversations With the Other Side",
#  'Wedding Day Murder: A Lucy Stone Mystery (Lucy Stone Mystery)',
#  'Welcome to Camp Nightmare (Goosebumps, No 9)',
#  'What you think of me is none of my business',
#  'When Bad Things Happen to Good People',
#  'When I Say No, I Feel Guilty',
#  'When Will This Cruel War Be Over? The Civil War Diary of Emma Simpson, Gordonsville, Virginia, 1864 (Dear America)',
#  "When You Look Like Your Passport Photo, It's Time to Go Home",
#  "Where the Heart Is (Oprah's Book Club (Paperback))",
#  'Where the Wild Things Are (Caldecott Collection)',
#  'White Elephant Dead: : A Death on Demand Mystery (Death on Demand Mysteries (Paperback))',
#  'White Teeth',
#  'Whose Body?',
#  'Wicked Slice',
#  'Wicked: The Life and Times of the Wicked Witch of the West',
#  'Wide Sargasso Sea (Norton Paperback Fiction)',
#  "Widower's House: A Study in Bereavement, or How Margot and Mella Forced Me to Flee My Home",
#  'Wild Horses',
#  'Winnie the Pooh',
#  'Wired: The Short Life and Fast Times of John Belushi',
#  'Wish You Were Here (Mrs. Murphy Mysteries (Paperback))',
#  'Woman of Independence',
#  'Women Who Run with the Wolves',
#  'Wondrous Beginnings',
#  'Word Freak: Heartbreak, Triumph, Genius, and Obsession in the World of Competitive Scrabble Players',
#  "Working Woman's Art of War: Winning Without Confrontation",
#  'Working Wounded: Advice That Adds Insight to Injury',
#  "Wouldn't It Be Nice?: My Own Story",
#  "Wuthering Heights (The World's Classics)",
#  'Xanth 13: Isle of View',
#  'Xanth 14: Question Quest',
#  'Xanth 15: The Color of Her Panties',
#  '\\O\\" Is for Outlaw"']

# %%
len(user_7346_books_rated)
# Out:
# 972

# %% [markdown]
# We see that our user has rated 883 books

# %% [markdown]
# We now create a new DF consisting of only the books that our user has rated. We will use this to look for similar users

# %%
books_rated_df = user_rating_books_df[user_7346_books_rated]

# %%
books_rated_df
# Out:
# Book-Title  10,000 Things to Praise God for  101 Dalmatians  1984  \
# User-ID
# 3363.0                                  NaN             NaN   NaN
# 6251.0                                  NaN             NaN   NaN
# 6575.0                                  NaN             NaN   NaN
# 7346.0                                  8.0            10.0   8.0
# 11601.0                                 NaN             NaN   NaN
# ...                                     ...             ...   ...
# 271284.0                                NaN             NaN   NaN
# 274061.0                                NaN             NaN   NaN
# 274308.0                                NaN             NaN   NaN
# 275970.0                                NaN             NaN   0.0
# 278418.0                                NaN             0.0   NaN
#
# Book-Title  36 Hour Day : A Family Guide to Caring for Person with          Alzheimer Disease  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    0.0
# 11601.0                                                   NaN
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  A 2nd Helping of Chicken Soup for the Soul (Chicken Soup for the Soul Series (Paper))  \
# User-ID
# 3363.0                                                    0.0
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    7.0
# 11601.0                                                   NaN
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    0.0
# 6575.0                                                    NaN
# 7346.0                                                    0.0
# 11601.0                                                   NaN
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  A CLEAR CASE OF MURDER  \
# User-ID
# 3363.0                         NaN
# 6251.0                         NaN
# 6575.0                         NaN
# 7346.0                         0.0
# 11601.0                        NaN
# ...                            ...
# 271284.0                       NaN
# 274061.0                       NaN
# 274308.0                       NaN
# 275970.0                       NaN
# 278418.0                       NaN
#
# Book-Title  A Child Called \It\": One Child's Courage to Survive"  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    0.0
# 11601.0                                                   0.0
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  A Civil Action  \
# User-ID
# 3363.0                 0.0
# 6251.0                 NaN
# 6575.0                 0.0
# 7346.0                 0.0
# 11601.0                NaN
# ...                    ...
# 271284.0               NaN
# 274061.0               NaN
# 274308.0               NaN
# 275970.0               NaN
# 278418.0               NaN
#
# Book-Title  A Cow on the Line and Other Thomas the Tank Engine Stories (Please Read to Me)  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    0.0
# 11601.0                                                   NaN
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  ...  Wondrous Beginnings  \
# User-ID     ...
# 3363.0      ...                  NaN
# 6251.0      ...                  NaN
# 6575.0      ...                  NaN
# 7346.0      ...                  0.0
# 11601.0     ...                  NaN
# ...         ...                  ...
# 271284.0    ...                  NaN
# 274061.0    ...                  NaN
# 274308.0    ...                  NaN
# 275970.0    ...                  NaN
# 278418.0    ...                  NaN
#
# Book-Title  Word Freak: Heartbreak, Triumph, Genius, and Obsession in the World of Competitive Scrabble Players  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    0.0
# 11601.0                                                   NaN
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  Working Woman's Art of War: Winning Without Confrontation  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    0.0
# 11601.0                                                   NaN
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  Working Wounded: Advice That Adds Insight to Injury  \
# User-ID
# 3363.0                                                    NaN
# 6251.0                                                    NaN
# 6575.0                                                    NaN
# 7346.0                                                    0.0
# 11601.0                                                   NaN
# ...                                                       ...
# 271284.0                                                  NaN
# 274061.0                                                  NaN
# 274308.0                                                  NaN
# 275970.0                                                  NaN
# 278418.0                                                  NaN
#
# Book-Title  Wouldn't It Be Nice?: My Own Story  \
# User-ID
# 3363.0                                     NaN
# 6251.0                                     NaN
# 6575.0                                     NaN
# 7346.0                                     0.0
# 11601.0                                    NaN
# ...                                        ...
# 271284.0                                   NaN
# 274061.0                                   NaN
# 274308.0                                   NaN
# 275970.0                                   NaN
# 278418.0                                   NaN
#
# Book-Title  Wuthering Heights (The World's Classics)  Xanth 13: Isle of View  \
# User-ID
# 3363.0                                           NaN                     NaN
# 6251.0                                           NaN                     NaN
# 6575.0                                           NaN                     NaN
# 7346.0                                           7.0                     6.0
# 11601.0                                          NaN                     NaN
# ...                                              ...                     ...
# 271284.0                                         NaN                     NaN
# 274061.0                                         NaN                    10.0
# 274308.0                                         NaN                     NaN
# 275970.0                                         NaN                     NaN
# 278418.0                                         NaN                     NaN
#
# Book-Title  Xanth 14: Question Quest  Xanth 15: The Color of Her Panties  \
# User-ID
# 3363.0                           NaN                                 NaN
# 6251.0                           NaN                                 NaN
# 6575.0                           NaN                                 NaN
# 7346.0                           6.0                                 6.0
# 11601.0                          NaN                                 NaN
# ...                              ...                                 ...
# 271284.0                         NaN                                 NaN
# 274061.0                         NaN                                10.0
# 274308.0                         NaN                                 NaN
# 275970.0                         NaN                                 NaN
# 278418.0                         NaN                                 NaN
#
# Book-Title  \O\" Is for Outlaw"
# User-ID
# 3363.0                      NaN
# 6251.0                      NaN
# 6575.0                      NaN
# 7346.0                      8.0
# 11601.0                     0.0
# ...                         ...
# 271284.0                    NaN
# 274061.0                    NaN
# 274308.0                    NaN
# 275970.0                    NaN
# 278418.0                    NaN
#
# [200 rows x 972 columns]

# %%
books_rated_df.shape
# Out:
# (200, 972)

# %% [markdown]
# To find similarity, we want to calculate how many books the other users have rated in regards to the selected books for user_7346

# %% [markdown]
# Here we transpose the books_rated_df. The columns becomes the rows and the rows becomes the columns. In other words: Each Book_title will be a row, and each column will be the userId and their rating for the book (if any). We get the .sum() of .notnull(): That is we get the number of non-NaN ratings for each user.

# %%
user_book_count = books_rated_df.T.notnull().sum()

# %%
user_book_count
# Out:
# User-ID
# 3363.0       57
# 6251.0       70
# 6575.0       82
# 7346.0      972
# 11601.0      82
#            ...
# 271284.0     40
# 274061.0     26
# 274308.0     62
# 275970.0     43
# 278418.0     82
# Length: 200, dtype: int64

# %% [markdown]
# Resetting index, and giving column names. This makes it easier to look interpret:

# %%
user_book_count = user_book_count.reset_index()
user_book_count.columns = ["User-ID", "book_count"]
user_book_count
# Out:
#       User-ID  book_count
# 0      3363.0          57
# 1      6251.0          70
# 2      6575.0          82
# 3      7346.0         972
# 4     11601.0          82
# ..        ...         ...
# 195  271284.0          40
# 196  274061.0          26
# 197  274308.0          62
# 198  275970.0          43
# 199  278418.0          82
#
# [200 rows x 2 columns]

# %% [markdown]
# We now filter away those user that has rated less than 20% of the books that our user 7346 has rated. User 7346 has a high number of rated books, thus we select a low "similarity score" of 15%. Ideally this would be set way higher, eg. at 70%. For now we stick with this value

# %%
user_same_books = user_book_count[user_book_count["book_count"] > (len(user_7346_books_rated)*15)/100]["User-ID"]
user_same_books
# Out:
# 3        7346.0
# 5       11676.0
# 25      35859.0
# 137    198711.0
# Name: User-ID, dtype: float64

# %% [markdown]
# The above shows us the userids (as the col) that have rated 15% or more of the same books as user 7346 has

# %% [markdown]
# We create a new DF consisting of the ratings of the users that satisfied the similarity as above

# %%
final_df = books_rated_df[books_rated_df.index.isin(user_same_books)]
final_df
# Out:
# Book-Title  10,000 Things to Praise God for  101 Dalmatians      1984  \
# User-ID
# 7346.0                                  8.0            10.0  8.000000
# 11676.0                                 NaN             NaN  3.333333
# 35859.0                                 NaN             NaN       NaN
# 198711.0                                NaN             0.0       NaN
#
# Book-Title  36 Hour Day : A Family Guide to Caring for Person with          Alzheimer Disease  \
# User-ID
# 7346.0                                                    0.0
# 11676.0                                                   NaN
# 35859.0                                                   NaN
# 198711.0                                                  NaN
#
# Book-Title  A 2nd Helping of Chicken Soup for the Soul (Chicken Soup for the Soul Series (Paper))  \
# User-ID
# 7346.0                                                    7.0
# 11676.0                                                   0.0
# 35859.0                                                   NaN
# 198711.0                                                  NaN
#
# Book-Title  A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash  \
# User-ID
# 7346.0                                                    0.0
# 11676.0                                                   0.0
# 35859.0                                                   0.0
# 198711.0                                                  NaN
#
# Book-Title  A CLEAR CASE OF MURDER  \
# User-ID
# 7346.0                         0.0
# 11676.0                        NaN
# 35859.0                        NaN
# 198711.0                       NaN
#
# Book-Title  A Child Called \It\": One Child's Courage to Survive"  \
# User-ID
# 7346.0                                                    0.0
# 11676.0                                                   0.0
# 35859.0                                                   0.0
# 198711.0                                                  NaN
#
# Book-Title  A Civil Action  \
# User-ID
# 7346.0                 0.0
# 11676.0                3.5
# 35859.0                NaN
# 198711.0               0.0
#
# Book-Title  A Cow on the Line and Other Thomas the Tank Engine Stories (Please Read to Me)  \
# User-ID
# 7346.0                                                    0.0
# 11676.0                                                   NaN
# 35859.0                                                   NaN
# 198711.0                                                  0.0
#
# Book-Title  ...  Wondrous Beginnings  \
# User-ID     ...
# 7346.0      ...                  0.0
# 11676.0     ...                  NaN
# 35859.0     ...                  NaN
# 198711.0    ...                  NaN
#
# Book-Title  Word Freak: Heartbreak, Triumph, Genius, and Obsession in the World of Competitive Scrabble Players  \
# User-ID
# 7346.0                                                    0.0
# 11676.0                                                   7.5
# 35859.0                                                   0.0
# 198711.0                                                  NaN
#
# Book-Title  Working Woman's Art of War: Winning Without Confrontation  \
# User-ID
# 7346.0                                                    0.0
# 11676.0                                                   NaN
# 35859.0                                                   NaN
# 198711.0                                                  NaN
#
# Book-Title  Working Wounded: Advice That Adds Insight to Injury  \
# User-ID
# 7346.0                                                    0.0
# 11676.0                                                   NaN
# 35859.0                                                   NaN
# 198711.0                                                  NaN
#
# Book-Title  Wouldn't It Be Nice?: My Own Story  \
# User-ID
# 7346.0                                     0.0
# 11676.0                                    NaN
# 35859.0                                    NaN
# 198711.0                                   NaN
#
# Book-Title  Wuthering Heights (The World's Classics)  Xanth 13: Isle of View  \
# User-ID
# 7346.0                                           7.0                     6.0
# 11676.0                                          NaN                     NaN
# 35859.0                                          NaN                     NaN
# 198711.0                                         NaN                     NaN
#
# Book-Title  Xanth 14: Question Quest  Xanth 15: The Color of Her Panties  \
# User-ID
# 7346.0                           6.0                                 6.0
# 11676.0                          NaN                                 NaN
# 35859.0                          NaN                                 NaN
# 198711.0                         NaN                                 NaN
#
# Book-Title  \O\" Is for Outlaw"
# User-ID
# 7346.0                      8.0
# 11676.0                     3.5
# 35859.0                     NaN
# 198711.0                    NaN
#
# [4 rows x 972 columns]

# %% [markdown]
# We now want to calculate the correlation between the users. We need to transpose the DF, as .corr() is calculating the correlation between columns.

# %%
example_df = final_df.T ##Showcasing the transposed df, as an example. 
example_df
# Out:
# User-ID                                             7346.0    11676.0   \
# Book-Title
# 10,000 Things to Praise God for                          8.0       NaN
# 101 Dalmatians                                          10.0       NaN
# 1984                                                     8.0  3.333333
# 36 Hour Day : A Family Guide to Caring for Pers...       0.0       NaN
# A 2nd Helping of Chicken Soup for the Soul (Chi...       7.0  0.000000
# ...                                                      ...       ...
# Wuthering Heights (The World's Classics)                 7.0       NaN
# Xanth 13: Isle of View                                   6.0       NaN
# Xanth 14: Question Quest                                 6.0       NaN
# Xanth 15: The Color of Her Panties                       6.0       NaN
# \O\" Is for Outlaw"                                      8.0  3.500000
#
# User-ID                                             35859.0   198711.0
# Book-Title
# 10,000 Things to Praise God for                          NaN       NaN
# 101 Dalmatians                                           NaN       0.0
# 1984                                                     NaN       NaN
# 36 Hour Day : A Family Guide to Caring for Pers...       NaN       NaN
# A 2nd Helping of Chicken Soup for the Soul (Chi...       NaN       NaN
# ...                                                      ...       ...
# Wuthering Heights (The World's Classics)                 NaN       NaN
# Xanth 13: Isle of View                                   NaN       NaN
# Xanth 14: Question Quest                                 NaN       NaN
# Xanth 15: The Color of Her Panties                       NaN       NaN
# \O\" Is for Outlaw"                                      NaN       NaN
#
# [972 rows x 4 columns]

# %% [markdown]
# Transposing and doing the correlation:

# %%
corr_df = final_df.T.corr()
corr_df
# Out:
# User-ID   7346.0    11676.0   35859.0   198711.0
# User-ID
# 7346.0    1.000000 -0.056281 -0.043172       NaN
# 11676.0  -0.056281  1.000000 -0.095168       NaN
# 35859.0  -0.043172 -0.095168  1.000000       NaN
# 198711.0       NaN       NaN       NaN       NaN

# %% [markdown]
# As expected, the correlation is quite bad

# %% [markdown]
# We now make a new DF which shows the correlation of the selected users, in regards to user 7346:

# %%
user_corr = corr_df[7346].reset_index() ##Resetting index, turning the correlation matrix from a series to a dataframe
user_corr
# Out:
#     User-ID    7346.0
# 0    7346.0  1.000000
# 1   11676.0 -0.056281
# 2   35859.0 -0.043172
# 3  198711.0       NaN

# %%
user_corr = user_corr.rename(columns={7346: "correlation"}) ##Renaming column "7346", so it instead is called correlation
user_corr
# Out:
#     User-ID  correlation
# 0    7346.0     1.000000
# 1   11676.0    -0.056281
# 2   35859.0    -0.043172
# 3  198711.0          NaN

# %%
user_corr = user_corr.sort_values(by="correlation", ascending=False)
user_corr
# Out:
#     User-ID  correlation
# 0    7346.0     1.000000
# 2   35859.0    -0.043172
# 1   11676.0    -0.056281
# 3  198711.0          NaN

# %%
user_corr = user_corr.loc[user_corr["User-ID"] != 7346]
user_corr
# Out:
#     User-ID  correlation
# 2   35859.0    -0.043172
# 1   11676.0    -0.056281
# 3  198711.0          NaN

# %%
user_corr = user_corr.reset_index(drop=True)
user_corr
# Out:
#     User-ID  correlation
# 0   35859.0    -0.043172
# 1   11676.0    -0.056281
# 2  198711.0          NaN

# %% [markdown]
# The above is now a sorted correlation matrix, that shows correlation between the selected users and user 7346 (where user 7346 is excluded)

# %% [markdown]
# We now merge the correlation df with the ratings df, giving us the correlated users, alongside the ISBN and their rating for that particular book. We use inner join as we only want to users that are present in both dataframes, to be included in the final result

# %%
top_users_ratings = user_corr.merge(ratings[["User-ID", "ISBN", "Book-Rating"]], how="inner")
top_users_ratings
# Out:
#         User-ID  correlation        ISBN  Book-Rating
# 0       35859.0    -0.043172  0004722124           10
# 1       35859.0    -0.043172  0006543936            0
# 2       35859.0    -0.043172  0006547230            0
# 3       35859.0    -0.043172  0007101937            0
# 4       35859.0    -0.043172  0020186002            0
# ...         ...          ...         ...          ...
# 26997  198711.0          NaN  8511839102            0
# 26998  198711.0          NaN  9307166813            0
# 26999  198711.0          NaN  9590624067            0
# 27000  198711.0          NaN  9631172937            0
# 27001  198711.0          NaN  9641930266            0
#
# [27002 rows x 4 columns]

# %% [markdown]
# Here we create the weighted ratings. More similar users and higher ratings will give us higher weighted ratings. In other words, the weighted rating helps us prioritize ratings of the users who are more similar to the input user.

# %%
top_users_ratings["weighted_rating"] = top_users_ratings["correlation"] * top_users_ratings["Book-Rating"]
top_users_ratings
# Out:
#         User-ID  correlation        ISBN  Book-Rating  weighted_rating
# 0       35859.0    -0.043172  0004722124           10        -0.431723
# 1       35859.0    -0.043172  0006543936            0        -0.000000
# 2       35859.0    -0.043172  0006547230            0        -0.000000
# 3       35859.0    -0.043172  0007101937            0        -0.000000
# 4       35859.0    -0.043172  0020186002            0        -0.000000
# ...         ...          ...         ...          ...              ...
# 26997  198711.0          NaN  8511839102            0              NaN
# 26998  198711.0          NaN  9307166813            0              NaN
# 26999  198711.0          NaN  9590624067            0              NaN
# 27000  198711.0          NaN  9631172937            0              NaN
# 27001  198711.0          NaN  9641930266            0              NaN
#
# [27002 rows x 5 columns]

# %% [markdown]
# We now calculate the mean weighted rating for all books. This final weighted rating can be regarded as how much the book is to be considered recommended for the input user

# %%
recommendation_df = top_users_ratings.groupby("ISBN").agg({"weighted_rating": "mean"}).sort_values(by = "weighted_rating", ascending = False)
recommendation_df = recommendation_df.reset_index() ## reset index, so that ISBN is not the index anymore
recommendation_df
# Out:
#                 ISBN  weighted_rating
# 0         O805063196              0.0
# 1         O77O428452              0.0
# 2      0 7336 1053 6              0.0
# 3         9997511417              0.0
# 4         9993763128              0.0
# ...              ...              ...
# 24710     8467003995              NaN
# 24711     8511839102              NaN
# 24712     9590624067              NaN
# 24713     9631172937              NaN
# 24714     9641930266              NaN
#
# [24715 rows x 2 columns]

# %%
books_to_be_recommended = recommendation_df.merge(books[["ISBN", "Book-Title"]], on="ISBN")
books_to_be_recommended = books_to_be_recommended.head()
books_to_be_recommended
# Out:
#          ISBN  weighted_rating  \
# 0  9997511417              0.0
# 1  9993763128              0.0
# 2  9871138016              0.0
# 3  0003252477              0.0
# 4  000617891X              0.0
#
#                                           Book-Title
# 0                              A Bundle for the Toff
# 1   Star Wars: From the Adventures of Luke Skywalker
# 2                    Cronica De Una Muerte Anunciada
# 3  A midsummer night's dream; (The Alexander Shak...
# 4                            At the Stroke of Twelve

# %% [markdown]
# # Not same result exactly, as some books dont have a book-title but only a ISBN

# %%
books.nunique()
# Out:
# ISBN                   271360
# Book-Title             242135
# Book-Author            102022
# Year-Of-Publication       202
# Publisher               16807
# Image-URL-S            271044
# Image-URL-M            271044
# Image-URL-L            271041
# dtype: int64

# %% [markdown]
# Now creating recommender function:

# %%
def user_based_recommender(input_user, user_rating_books_df, rate_ratio=0.70, num_recommendations=5):

    input_user_df = user_rating_books_df[user_rating_books_df.index == input_user]
    input_user_books_rated = input_user_df.columns[input_user_df.notna().any()].tolist()

    books_rated_df = user_rating_books_df[input_user_books_rated]


    user_book_count = books_rated_df.T.notnull().sum()
    user_book_count = user_book_count.reset_index()
    user_book_count.columns = ["User-ID", "book_count"]

    user_same_books = user_book_count[user_book_count["book_count"] > (len(input_user_books_rated)*rate_ratio)]["User-ID"]


    final_df = books_rated_df[books_rated_df.index.isin(user_same_books)]
    corr_df = final_df.T.corr()


    user_corr = corr_df[input_user].reset_index()
    user_corr = user_corr.rename(columns={input_user: "correlation"})
    user_corr = user_corr.sort_values(by="correlation", ascending=False)
    user_corr = user_corr.loc[user_corr["User-ID"] != input_user]
    user_corr = user_corr.reset_index(drop=True)


    top_users_ratings = user_corr.merge(ratings[["User-ID", "ISBN", "Book-Rating"]], how="inner")
    top_users_ratings["weighted_rating"] = top_users_ratings["correlation"] * top_users_ratings["Book-Rating"]


    recommendation_df = top_users_ratings.groupby("ISBN").agg({"weighted_rating": "mean"}).sort_values(by = "weighted_rating", ascending = False)
    recommendation_df = recommendation_df.reset_index()


    books_to_be_recommended = recommendation_df.merge(books[["ISBN", "Book-Title"]], on="ISBN")
    books_to_be_recommended = books_to_be_recommended.head(num_recommendations)

    return books_to_be_recommended["Book-Title"]

# %%
user_based_recommender(6575, user_rating_books_df, 0.25)
# Out:
# 0           Three's a Crowd (Sweet Valley Twins, No 7)
# 1    Encyclopedia Brown: Boy Detective (Encyclopedi...
# 2    David Letterman's Book of Top Ten Lists and Ze...
# 3                               Hawk O'Toole's Hostage
# 4                                         Miracle Cure
# Name: Book-Title, dtype: object

# %% [markdown]
# ## Exercise 2
#
# Using the "Coursera Courses Dataset 2021" from Exercise 1, to do the following:
#
# 1. [Optional] Create a Content-based filtering recommender system based on both the Course Descriptions and the Skills.
# 2. [Optional] Can you come up with a way of including Difficulty Level and Course Rating in your recommender system?
